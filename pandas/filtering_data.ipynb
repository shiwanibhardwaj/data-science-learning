# %%
import pandas as pd
data=pd.read_json("students_data.json")
data
data[data["Student_ID"]>120]
# Out:
#     Student_ID           Name   Age  Gender     City            Course  Marks  \
# 20         121   Aarav Sharma  20.0    Male    Delhi      Data Science   85.0
# 21         122  Ritika Sharma  25.0  Female   Delhi      Data Science   105.0
# 22         123    Mohit Kumar  17.0       M    DELHI            Python   55.0
# 23         124    Simran Kaur  26.0       F    delhi  Machine Learning   88.0
# 24         125      Raj Gupta  -5.0    Male    Delhi            Python   62.0
# 25         126     Poonam Roy  21.0  Female   Mumbai           Web Dev   79.0
# 26         127    Vivek Singh  22.0    Male   Mumbai   Web Development   79.0
# 27         128    Neha Kapoor  22.0  Female   Mumbai      Data Science   89.0
# 28         129    Aditi Joshi  21.0  Female    Delhi      Data Science   88.0
# 29         130   Ramesh Kumar  23.0    Male    Patna            Python   72.0
#
#     Attendance  Study_Hours             Email       Phone   Join_Date  \
# ...

# %%
# filtering data using query (query returns copy not view)
data.query("Student_ID > 120 & Age >20")[["Name","Age",'Phone']]

#by python variable
var=120
data.query("Student_ID >@var & Age >20")[["Name","Age",'Phone']]
# Out:
#              Name   Age       Phone
# 21  Ritika Sharma  25.0  9876543230
# 23    Simran Kaur  26.0  9876543232
# 25     Poonam Roy  21.0  9876543234
# 26    Vivek Singh  22.0  9876543235
# 27    Neha Kapoor  22.0  9876543219
# 28    Aditi Joshi  21.0  9876543237
# 29   Ramesh Kumar  23.0  9876543238
