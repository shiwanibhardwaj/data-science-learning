# %%
import pandas as pd
data =pd.read_csv('student_data.csv')
data
# Out:
#    Student_ID    Name   Age  Gender  Math_Score  Science_Score  Attendance  \
# 0         101    Amit  20.0    Male        85.0           78.0        90.0
# 1         102    Neha  21.0  Female        88.0            NaN        85.0
# 2         103   Rahul   NaN    Male        70.0           65.0         NaN
# 3         104   Priya  22.0  Female         NaN           72.0        88.0
# 4         105   Ankit  20.0    Male        60.0           55.0        75.0
# 5         106  Simran  21.0  Female        92.0           89.0         NaN
# 6         107     NaN  23.0    Male        75.0            NaN        80.0
# 7         108   Kavya  22.0  Female        80.0           77.0        92.0
#
#         City
# 0      Delhi
# 1     Mumbai
# 2  Bangalore
# 3        NaN
# 4      Delhi
# 5    Chennai
# 6  Hyderabad
# 7     Mumbai

# %%
data.isnull()
# Out:
#    Student_ID   Name    Age  Gender  Math_Score  Science_Score  Attendance  \
# 0       False  False  False   False       False          False       False
# 1       False  False  False   False       False           True       False
# 2       False  False   True   False       False          False        True
# 3       False  False  False   False        True          False       False
# 4       False  False  False   False       False          False       False
# 5       False  False  False   False       False          False        True
# 6       False   True  False   False       False           True       False
# 7       False  False  False   False       False          False       False
#
#     City
# 0  False
# 1  False
# 2  False
# 3   True
# 4  False
# 5  False
# 6  False
# 7  False

# %%
data.isnull().sum()
# Out:
# Student_ID       0
# Name             1
# Age              1
# Gender           0
# Math_Score       1
# Science_Score    2
# Attendance       2
# City             1
# dtype: int64

# %%
data.dropna(axis=1)
# Out:
#    Student_ID  Gender
# 0         101    Male
# 1         102  Female
# 2         103    Male
# 3         104  Female
# 4         105    Male
# 5         106  Female
# 6         107    Male
# 7         108  Female

# %%
data.dropna(how='any')
# Out:
#    Student_ID   Name   Age  Gender  Math_Score  Science_Score  Attendance  \
# 0         101   Amit  20.0    Male        85.0           78.0        90.0
# 4         105  Ankit  20.0    Male        60.0           55.0        75.0
# 7         108  Kavya  22.0  Female        80.0           77.0        92.0
#
#      City
# 0   Delhi
# 4   Delhi
# 7  Mumbai

# %%
data.fillna(0)
# Out:
#    Student_ID    Name   Age  Gender  Math_Score  Science_Score  Attendance  \
# 0         101    Amit  20.0    Male        85.0           78.0        90.0
# 1         102    Neha  21.0  Female        88.0            0.0        85.0
# 2         103   Rahul   0.0    Male        70.0           65.0         0.0
# 3         104   Priya  22.0  Female         0.0           72.0        88.0
# 4         105   Ankit  20.0    Male        60.0           55.0        75.0
# 5         106  Simran  21.0  Female        92.0           89.0         0.0
# 6         107       0  23.0    Male        75.0            0.0        80.0
# 7         108   Kavya  22.0  Female        80.0           77.0        92.0
#
#         City
# 0      Delhi
# 1     Mumbai
# 2  Bangalore
# 3          0
# 4      Delhi
# 5    Chennai
# 6  Hyderabad
# 7     Mumbai

# %%
data['City'].fillna('unknown')
# Out:
# 0        Delhi
# 1       Mumbai
# 2    Bangalore
# 3      unknown
# 4        Delhi
# 5      Chennai
# 6    Hyderabad
# 7       Mumbai
# Name: City, dtype: object

# %%
data['Age'].fillna(data['Age'].mean())
# Out:
# 0    20.000000
# 1    21.000000
# 2    21.285714
# 3    22.000000
# 4    20.000000
# 5    21.000000
# 6    23.000000
# 7    22.000000
# Name: Age, dtype: float64
