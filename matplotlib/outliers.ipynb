# %% [markdown]
# IQR
# sort the data
# calculate Q1 & Q3
# IQR=Q3-Q1
# lower fence=Q1-1.5(IQR)
# upper fence=Q3+1.5(IQR)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

dataset=[1,2,3,4,5,6,6,7,8,9,9,8,5,10,19,181,5,16,13,14,38,49,109,150]
outliers=[]
plt.hist(dataset)


#finding outliers....
def identify_outliers(data):
  threshold=3
  mean=np.mean(data)
  std=np.std(data)
  for i in data:
    z_score=(i-mean)/std
    if np.abs(z_score)>threshold:
      outliers.append(i)
  return outliers

print(identify_outliers(dataset))


#calculate Q1 & Q3

q1,q3=np.percentile(dataset,[25,75])
iqr=q3-q1
lower_fence=q1-(1.5*iqr)
upper_fence=q3+(1.5*iqr)
print(lower_fence)
print(upper_fence)

sns.boxplot(dataset)
# Out:
# [181]
# -12.625
# 34.375
# <Axes: >
