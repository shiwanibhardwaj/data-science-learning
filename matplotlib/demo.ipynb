# %% [raw]
# import matplotlib.pyplot as plt

# %%
x=["python","c","c++","java"]
y=[4,5,6,7]
c=['r','g','b','y']
plt.xlabel("languages" ,fontsize=12)
plt.ylabel("numbers")
plt.title("barchart")
plt.bar(x,y,color=c,width=0.5,align="edge",edgecolor='b',linewidth=2,linestyle="dotted",alpha=0.5,label="popularity")
plt.legend()
plt.show()
