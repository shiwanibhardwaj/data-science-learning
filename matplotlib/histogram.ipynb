# %%
import matplotlib.pyplot as plt
import numpy as np
import random
x=np.random.randint(10,60,(40))
print(x)
# Out:
# [48 42 32 19 22 38 27 46 30 33 21 37 30 55 18 12 12 39 28 17 15 21 40 15
#  26 35 37 51 59 43 20 42 20 26 26 35 35 48 29 30]

# %%
num=[41, 25, 10 ,51, 11, 47, 46 ,41, 10, 42, 36, 48 ,49 ,28 ,14, 17 ,20 ,41 ,19 ,38, 55 ,40 ,21 ,11,
 51, 19, 32, 48, 50, 10, 40, 30, 17, 36, 47, 41 ,56 ,35 ,35 ,26]
plt.xlabel("numbers")
plt.ylabel('popular')
l=[10,20,30,40,50,60]
plt.hist(num, bins='auto', range=(0, 100), edgecolor='y' ,cumulative=-1 ,
bottom=10,align='left',histtype='step',orientation='horizontal',rwidth=0.4, log='true')
plt.axvline(25,color='b',label="line")
plt.legend()
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt


x=[13,21,35,41,64]
plt.xlabel("points")
plt.ylabel("numbers")
plt.title("histogram")
plt.hist(x,label="chart",edgecolor='r')
plt.legend()
plt.show()
